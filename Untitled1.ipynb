# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Load the data
df = pd.read_csv('dataset.csv')
df.drop(columns='Unnamed: 0', inplace=True)

# %%
plt.figure(figsize=(8,4))
plt.hist(df['popularity'],bins=100)
plt.title('Distribution of Popularity', fontsize=14, fontweight='bold')
plt.xlabel('Popularity Score')
plt.ylabel('Frequency')
plt.savefig('pop_distribution.png')
plt.show()

# %%
plt.hist(df1['popularity'],bins=99)
plt.show()

# %%
df1 = df[df['popularity']>0]

# %%
df2 = df[df['popularity']>49]

# %%
(df.shape[0] - df1.shape[0]) / df.shape[0]
# Out:
# 0.1405263157894737

# %%
(df.shape[0] - df2.shape[0]) / df.shape[0]
# Out:
# 0.7423947368421052
